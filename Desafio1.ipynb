# %% [markdown]
# #Desafío 1

# %% [markdown]
# ##Recopilación y muestra de datos
#
# ### 1 - Crea un programa que solicite al usuario que escriba su nombre y luego imprima "Hola, [nombre]."

# %%
nombre = input("Escribe tu nombre: ")
print(f'Hola, {nombre} ')

# %% [markdown]
# ### 2 - Crea un programa que solicite al usuario que escriba su nombre y edad, y luego imprima "Hola, [nombre], tienes [edad] años."

# %%
nombre = input("Escribe tu nombre: ")
edad = int(input("Escribe tu edad: "))
print(f'Hola, {nombre}, tienes {edad} años.')

# %% [markdown]
# ### 3 - Crea un programa que solicite al usuario que escriba su nombre, edad y altura en metros, y luego imprima "Hola, [nombre], tienes [edad] años y mides [altura] metros."

# %%
nombre = input("Escribe tu nombre: ")
edad = int(input("Escribe tu edad: "))
altura = float(input("Escribe tu altura en metros: "))
print(f'Hola, {nombre}, tienes {edad} años y mides {altura} metros.')

# %% [markdown]
# ##Calculadora con operadores
#
# ###4 - Crea un programa que solicite dos valores numéricos al usuario y luego imprima la suma de ambos valores.

# %%
valor1 = int(input("Escribe el primer valor: "))
valor2 = int(input("Escribe el segundo valor: "))
print(f'La suma de los valores es: {valor1 + valor2}')

# %% [markdown]
# ###5 - Crea un programa que solicite tres valores numéricos al usuario y luego imprima la suma de los tres valores.

# %%
valor1 = int(input("Escribe el primer valor: "))
valor2 = int(input("Escribe el segundo valor: "))
valor3 = int(input("Escribe el tercer valor: "))
print(f'La suma de los valores es: {valor1 + valor2 + valor3}')

# %% [markdown]
# ###6 - Crea un programa que solicite dos valores numéricos al usuario y luego imprima la resta del primero menos el segundo valor.

# %%
valor1 = int(input("Escribe el primer valor: "))
valor2 = int(input("Escribe el segundo valor: "))
print(f'La resta de los valores es: {valor1 - valor2}')

# %% [markdown]
# ###7 - Crea un programa que solicite dos valores numéricos al usuario y luego imprima la multiplicación de los dos valores.

# %%
valor1 = int(input("Escribe el primer valor: "))
valor2 = int(input("Escribe el segundo valor: "))
print(f'La multiplicación de los valores es: {valor1 * valor2}')

# %% [markdown]
# ###8 - Crea un programa que solicite dos valores numéricos, un numerador y un denominador, y realice la división entre los dos valores. **Asegúrate de que el valor del denominador no sea igual a 0**.

# %%
numerador = int(input("Escribe el primer valor: "))
denominador = int(input("Escribe el segundo valor(este no puede ser nulo o 0): "))
print(f'La división de los valores es: {valor1 / valor2}')

# %% [markdown]
# ###9 - Crea un programa que solicite dos valores numéricos, un operador y una potencia, y realice la exponenciación entre estos dos valores.

# %%
valor1 = int(input("Escribe el primer valor: "))
valor2 = int(input("Escribe el segundo valor: "))
print(f'La exponenciación de los valores es: {valor1 ** valor2}')

# %% [markdown]
# ###10 - Crea un programa que solicite dos valores numéricos, un numerador y un denominador, y realice la división entera entre los dos valores. Asegúrate de que el valor del denominador no sea igual a 0.

# %%
numerador = int(input("Escribe el primer valor: "))
denominador = int(input("Escribe el segundo valor(este no puede ser nulo o 0): "))
print(f'La división entera de los valores es: {numerador // denominador}')

# %% [markdown]
# ###11 - Crea un programa que solicite dos valores numéricos, un numerador y un denominador, y devuelva el resto de la división entre los dos valores. Asegúrate de que el valor del denominador no sea igual a 0.

# %%
numerador = int(input("Escribe el primer valor: "))
denominador = int(input("Escribe el segundo valor(este no puede ser nulo o 0): "))
print(f'El resto de la división de los valores es: {numerador % denominador}')

# %% [markdown]
# ###12 - Crea un código que solicite las 3 notas de un estudiante e imprima el promedio de las notas.

# %%
nota1 = float(input("Escribe la primera nota: "))
nota2 = float(input("Escribe la segunda nota: "))
nota3 = float(input("Escribe la tercera nota: "))
print(f'El promedio de las notas es: {(nota1 + nota2 + nota3) / 3}')

# %% [markdown]
# ###13 - Crea un código que calcule e imprima el promedio ponderado de los números 5, 12, 20 y 15 con pesos respectivamente iguales a 1, 2, 3 y 4.

# %%
media = (5 * 1 + 12 * 2 + 20 * 3 + 15 * 4) / (1 + 2 + 3 + 4)
print(f'El promedio ponderado es: {media}')

# %% [markdown]
# ##Editando textos
#
# ###14 - Crea una variable llamada "frase" y asígnale una cadena de texto de tu elección. Luego, imprime la frase en pantalla.

# %%
frase = "!Estamos haciendo el desafío!"
print(frase)

# %% [markdown]
# ###15 - Crea un código que solicite una frase y luego imprima la frase en pantalla.

# %%
frase = input("Escribe una frase: ")
print(frase)

# %% [markdown]
# ###16 - Crea un código que solicite una frase al usuario y luego imprima la misma frase ingresada pero en mayúsculas.

# %%
frase = input("Escribe una frase: ")
print(frase.upper())

# %% [markdown]
# ###17 - Crea un código que solicite una frase al usuario y luego imprima la misma frase ingresada pero en minúsculas.

# %%
frase =  input("Escribe una frase: ")
print(frase.lower())

# %% [markdown]
# ###18 - Crea una variable llamada "frase" y asígnale una cadena de texto de tu elección. Luego, imprime la frase sin espacios en blanco al principio y al final.

# %%
frase = "  eliminando espacios  "
print(frase.strip())

# %% [markdown]
# ###19 - Crea un código que solicite una frase al usuario y luego imprima la misma frase sin espacios en blanco al principio y al final.

# %%
frase = input("Escribe una frase: ")
print(frase.strip())

# %% [markdown]
# ###20 - Crea un código que solicite una frase al usuario y luego imprima la misma frase sin espacios en blanco al principio y al final, además de convertirla a minúsculas.

# %%
frase = input("Escribe una frase: ")
print(frase.strip().lower())

# %% [markdown]
# ###21 - Crea un código que solicite una frase al usuario y luego imprima la misma frase con todas las vocales "e" reemplazadas por la letra "f".

# %%
frase = input("Escribe una frase: ")
print(frase.replace("e", "f"))

# %% [markdown]
# ###22 - Crea un código que solicite una frase al usuario y luego imprima la misma frase con todas las vocales "a" reemplazadas por el carácter "@".

# %%
frase = input("Escribe una frase: ")
print(frase.replace("a", "@"))

# %% [markdown]
# ###23 - Crea un código que solicite una frase al usuario y luego imprima la misma frase con todas las consonantes "s" reemplazadas por el carácter "$".

# %%
frase = input("Escribe una frase: ")
print(frase.replace("s", "$"))
